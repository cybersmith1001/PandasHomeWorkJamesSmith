# %% [markdown]
# <h1>Tackling an open problem</h1>
#
# For this homework the idea is to hone our skills on exploring and plotting a dataset. You can either work with the Pokemon dataset that was given or download your own. If you opt to download your own I recommend you use one of the datasets available on kaggle,
#
# https://www.kaggle.com/datasets
#
# As they tend to be found in a clean format and are generally free to use.
#
# Largely, the main objective is learning how to search the internet for new implementations you want to use on your code helping you develop your self-confidence.
#
# There's no right or wrong, pick a dataset you enjoy and try to have some fun.
# If you need, use the notebook from the previous session as a guideline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
CrimeStats_df = pd.read_csv(r'C:\Users\cyber\Desktop\CrimeStats.csv', sep=',')

# %%
print(CrimeStats_df)
# Out:
#     Area Code                     Area Name  \
# 0   K04000001  ENGLAND AND WALES [note 3]\n
# 1   E92000001                      ENGLAND
# 2   E12000001                    North East
# 3   E23000013                     Cleveland
# 4   E23000008                        Durham
# 5   E23000007                   Northumbria
# 6   E12000002                    North West
# 7   E23000006                      Cheshire
# 8   E23000002                       Cumbria
# 9   E23000005            Greater Manchester
# 10  E23000003                    Lancashire
# 11  E23000004                    Merseyside
# 12  E12000003      Yorkshire and The Humber
# 13  E23000012                    Humberside
# 14  E23000009      North Yorkshire [note 4]
# 15  E23000011               South Yorkshire
# 16  E23000010                West Yorkshire
# 17  E12000004                 East Midlands
# 18  E23000018                    Derbyshire
# 19  E23000021                Leicestershire
# ...

# %%
CrimeStats_df.head()
# Out:
#    Area Code                     Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]\n
# 1  E92000001                      ENGLAND
# 2  E12000001                    North East
# 3  E23000013                     Cleveland
# 4  E23000008                        Durham
#
#   Total recorded crime\n (excluding fraud) [note 2]  \
# 0                                         5,572,143
# 1                                         5,228,654
# 2                                           296,702
# 3                                            83,890
# 4                                            66,782
#
#   Violence against the person  Homicide Violence with injury  \
# 0                   2,102,843       602              573,402
# 1                   1,974,664       573              540,855
# 2                     112,488        41               30,936
# 3                      31,497        15                7,576
# 4                      26,919         9                5,852
#
# ...

# %%
CrimeStats_df.tail()
# Out:
#     Area Code                 Area Name  \
# 51  W15000004               Dyfed-Powys
# 52  W15000002                     Gwent
# 53  W15000001               North Wales
# 54  W15000003               South Wales
# 55        NaN  British Transport Police
#
#    Total recorded crime\n (excluding fraud) [note 2]  \
# 51                                            44,031
# 52                                            60,226
# 53                                            61,203
# 54                                           109,376
# 55                                            68,653
#
#    Violence against the person  Homicide Violence with injury  \
# 51                      21,501         5                3,901
# 52                      24,824         8                6,344
# 53                      28,844         5                6,696
# 54                      41,034         9               12,346
# 55                      11,976         2                3,260
#
# ...

# %%
CrimeStats_df.describe()
# Out:
#          Homicide
# count   56.000000
# mean    42.446429
# std    108.949349
# min      0.000000
# 25%      7.000000
# 50%     14.000000
# 75%     29.750000
# max    602.000000

# %%
CrimeStats_df.describe()
# Out:
#          Homicide
# count   56.000000
# mean    42.446429
# std    108.949349
# min      0.000000
# 25%      7.000000
# 50%     14.000000
# 75%     29.750000
# max    602.000000

# %%
CrimeStats_df = pd.read_csv(r'C:\Users\cyber\Desktop\CrimeStats.csv', sep=',')

# %%
CrimeStats_df.describe()
# Out:
#        Total recorded crime\n (excluding fraud) [note 2]  \
# count                                       5.600000e+01
# mean                                        3.906505e+05
# std                                         9.986040e+05
# min                                         7.298000e+03
# 25%                                         6.467125e+04
# 50%                                         1.057700e+05
# 75%                                         3.008292e+05
# max                                         5.572143e+06
#
#        Violence against the person    Homicide  Violence with injury  \
# count                 5.600000e+01   56.000000             56.000000
# mean                  1.477003e+05   42.446429          40317.875000
# std                   3.757617e+05  108.949349         102712.580292
# min                   1.132000e+03    0.000000            308.000000
# 25%                   2.668100e+04    7.000000           6619.250000
# ...

# %%
CrimeStats_df['Robbery']
# Out:
# 0     77337
# 1     74702
# 2      2194
# 3       952
# 4       207
# 5      1035
# 6      7954
# 7       398
# 8       173
# 9      5097
# 10     1046
# 11     1240
# 12     6189
# 13      878
# 14      211
# 15     1941
# 16     3159
# 17     3756
# 18      764
# 19      807
# 20      371
# 21      778
# 22     1036
# 23    10613
# 24      887
# 25      360
# 26      675
# 27     8691
# 28     4060
# 29      556
# 30      658
# 31     1550
# 32      684
# 33      351
# 34      261
# 35    31157
# 36      137
# 37    31020
# 38     5228
# 39     1369
# 40     1175
# 41      480
# 42      959
# 43     1245
# 44     3551
# 45     1763
# 46      624
# 47      441
# 48      373
# 49      350
# 50     1008
# 51       80
# 52      319
# 53      143
# 54      466
# 55     1627
# Name: Robbery, dtype: int64

# %%
len(CrimeStats_df['Robbery'])
# Out:
# 56

# %%
CrimeStats_df[['Death or serious injury - unlawful driving','Theft offences','Robbery']]
# Out:
#     Death or serious injury - unlawful driving  Theft offences  Robbery
# 0                                         1051         1740729    77337
# 1                                         1011         1647207    74702
# 2                                           36           83286     2194
# 3                                           16           23688      952
# 4                                           12           15931      207
# 5                                            8           43667     1035
# 6                                          176          198484     7954
# 7                                            6           18511      398
# 8                                           31            7882      173
# 9                                           78          101230     5097
# 10                                           7           36634     1046
# 11                                          54           34227     1240
# ...

# %%
CrimeStats_df['Area Name']
# Out:
# 0     ENGLAND AND WALES [note 3]\n
# 1                         ENGLAND
# 2                       North East
# 3                        Cleveland
# 4                           Durham
# 5                      Northumbria
# 6                       North West
# 7                         Cheshire
# 8                          Cumbria
# 9               Greater Manchester
# 10                      Lancashire
# 11                      Merseyside
# 12        Yorkshire and The Humber
# 13                      Humberside
# 14        North Yorkshire [note 4]
# 15                 South Yorkshire
# 16                  West Yorkshire
# 17                   East Midlands
# 18                      Derbyshire
# 19                  Leicestershire
# 20                    Lincolnshire
# 21                Northamptonshire
# 22                 Nottinghamshire
# 23                   West Midlands
# 24                   Staffordshire
# 25                    Warwickshire
# 26                     West Mercia
# ...

# %%
CrimeStats_df.keys()
# Out:
# Index(['Area Code', 'Area Name',
#        'Total recorded crime\n (excluding fraud) [note 2]',
#        'Violence against the person', 'Homicide', 'Violence with injury',
#        'Violence without injury', 'Stalking and harassment',
#        'Death or serious injury - unlawful driving', 'Sexual offences',
#        'Robbery', 'Theft offences', 'Burglary', 'Residential burglary',
#        'Non-residential burglary', 'Vehicle offences', 'Theft from the person',
#        'Bicycle theft', 'Shoplifting', 'Other theft offences',
#        'Criminal damage and arson', 'Drug offences',
#        'Possession of weapons offences', 'Public order offences',
#        'Miscellaneous crimes'],
#       dtype='object')

# %%
CrimeStats_df.columns
# Out:
# Index(['Area Code', 'Area Name',
#        'Total recorded crime\n (excluding fraud) [note 2]',
#        'Violence against the person', 'Homicide', 'Violence with injury',
#        'Violence without injury', 'Stalking and harassment',
#        'Death or serious injury - unlawful driving', 'Sexual offences',
#        'Robbery', 'Theft offences', 'Burglary', 'Residential burglary',
#        'Non-residential burglary', 'Vehicle offences', 'Theft from the person',
#        'Bicycle theft', 'Shoplifting', 'Other theft offences',
#        'Criminal damage and arson', 'Drug offences',
#        'Possession of weapons offences', 'Public order offences',
#        'Miscellaneous crimes'],
#       dtype='object')

# %%
CrimeStats_df['Area Name'].unique()
# Out:
# array(['ENGLAND AND WALES [note 3]\n', 'ENGLAND ', 'North East',
#        'Cleveland', 'Durham', 'Northumbria', 'North West', 'Cheshire',
#        'Cumbria', 'Greater Manchester', 'Lancashire', 'Merseyside',
#        'Yorkshire and The Humber', 'Humberside',
#        'North Yorkshire [note 4]', 'South Yorkshire', 'West Yorkshire',
#        'East Midlands', 'Derbyshire', 'Leicestershire', 'Lincolnshire',
#        'Northamptonshire', 'Nottinghamshire', 'West Midlands',
#        'Staffordshire', 'Warwickshire', 'West Mercia', 'East ',
#        'Bedfordshire', 'Cambridgeshire', 'Essex', 'Hertfordshire',
#        'Norfolk', 'Suffolk', 'London', 'City of London',
#        'Metropolitan Police', 'South East', 'Hampshire', 'Kent', 'Surrey',
#        'Sussex', 'Thames Valley', 'South West', 'Avon and Somerset',
#        'Devon and Cornwall', 'Dorset', 'Gloucestershire', 'Wiltshire',
#        'WALES', 'Dyfed-Powys', 'Gwent', 'North Wales', 'South Wales',
# ...

# %%
pwd
# Out:
# 'c:\\Users\\cyber\\Desktop'

# %%
CrimeStats_df.to_csv('c:\\users\\cyber\\Desktop\test.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\cyber\Desktop\Pandas homework.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cyber/Desktop/Pandas%20homework.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> CrimeStats_df.to_csv('c:\\users\\cyber\\Desktop\test.csv', sep=',')
#
# File c:\Users\cyber\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# ...

# %%
CrimeStats_df['Homicide'] / 52
# Out:
# 0     11.576923
# 1     11.019231
# 2      0.788462
# 3      0.288462
# 4      0.173077
# 5      0.326923
# 6      1.461538
# 7      0.076923
# 8      0.019231
# 9      0.673077
# 10     0.269231
# 11     0.423077
# 12     1.230769
# 13     0.269231
# 14     0.096154
# 15     0.326923
# 16     0.538462
# 17     0.942308
# 18     0.192308
# 19     0.153846
# 20     0.153846
# 21     0.173077
# 22     0.269231
# 23     1.423077
# 24     0.230769
# 25     0.076923
# 26     0.307692
# 27     0.807692
# 28     0.942308
# 29     0.307692
# 30     0.134615
# 31     0.250000
# 32     0.057692
# 33     0.038462
# 34     0.153846
# 35     2.192308
# 36     0.000000
# 37     2.192308
# 38     1.211538
# 39     0.346154
# 40     0.307692
# 41     0.076923
# 42     0.211538
# 43     0.269231
# 44     0.826923
# 45     0.307692
# 46     0.230769
# 47     0.076923
# 48     0.134615
# 49     0.076923
# 50     0.519231
# 51     0.096154
# 52     0.153846
# 53     0.096154
# 54     0.173077
# ...

# %%
CrimeStats_df['Drug offences'] / 52
# Out:
# 0     3459.115385
# 1     3246.903846
# 2      134.634615
# 3       47.230769
# 4       28.750000
# 5       58.653846
# 6      582.365385
# 7       51.500000
# 8       24.865385
# 9      233.288462
# 10      48.000000
# 11     224.711538
# 12     307.961538
# 13      29.384615
# 14      26.519231
# 15      84.538462
# 16     167.519231
# 17     254.769231
# 18      40.711538
# 19      63.519231
# 20      30.211538
# 21      41.480769
# 22      78.846154
# 23     260.442308
# 24      48.250000
# 25      19.461538
# 26      39.730769
# 27     153.000000
# 28     287.557692
# 29      34.365385
# 30      34.557692
# 31     107.076923
# 32      41.519231
# 33      40.384615
# 34      29.653846
# 35     796.711538
# 36      10.576923
# 37     786.134615
# 38     434.634615
# 39     109.500000
# 40      99.538462
# 41      45.538462
# 42      67.942308
# 43     112.115385
# 44     187.826923
# 45      51.403846
# 46      74.769231
# 47      19.788462
# 48      21.192308
# 49      20.673077
# ...

# %%
CrimeStats_df['Weekly Drug Offences'] = CrimeStats_df['Drug offences']/52

# %%
CrimeStats_df.head()
# Out:
#    Area Code                     Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]\n
# 1  E92000001                      ENGLAND
# 2  E12000001                    North East
# 3  E23000013                     Cleveland
# 4  E23000008                        Durham
#
#    Total recorded crime\n (excluding fraud) [note 2]  \
# 0                                            5572143
# 1                                            5228654
# 2                                             296702
# 3                                              83890
# 4                                              66782
#
#    Violence against the person  Homicide  Violence with injury  \
# 0                      2102843       602                573402
# 1                      1974664       573                540855
# 2                       112488        41                 30936
# 3                        31497        15                  7576
# ...

# %%
CrimeStats_df['Theft'] = CrimeStats_df['Theft from the person'] + CrimeStats_df['Bicycle theft'] + CrimeStats_df['Shoplifting'] + CrimeStats_df['Other theft offences']

# %%
CrimeStats_df.head()
# Out:
#    Area Code                     Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]\n
# 1  E92000001                      ENGLAND
# 2  E12000001                    North East
# 3  E23000013                     Cleveland
# 4  E23000008                        Durham
#
#    Total recorded crime\n (excluding fraud) [note 2]  \
# 0                                            5572143
# 1                                            5228654
# 2                                             296702
# 3                                              83890
# 4                                              66782
#
#    Violence against the person  Homicide  Violence with injury  \
# 0                      2102843       602                573402
# 1                      1974664       573                540855
# 2                       112488        41                 30936
# 3                        31497        15                  7576
# ...

# %%
CrimeStats_df.drop(['Violence against the person','Homicide','Violence with injury', 'Violence without injury', 'Stalking and harassment', 'Death or serious injury - unlawful driving', 'Sexual offences',  ], axis=1)
# Out:
#     Area Code                     Area Name  \
# 0   K04000001  ENGLAND AND WALES [note 3]\n
# 1   E92000001                      ENGLAND
# 2   E12000001                    North East
# 3   E23000013                     Cleveland
# 4   E23000008                        Durham
# 5   E23000007                   Northumbria
# 6   E12000002                    North West
# 7   E23000006                      Cheshire
# 8   E23000002                       Cumbria
# 9   E23000005            Greater Manchester
# 10  E23000003                    Lancashire
# 11  E23000004                    Merseyside
# 12  E12000003      Yorkshire and The Humber
# 13  E23000012                    Humberside
# 14  E23000009      North Yorkshire [note 4]
# 15  E23000011               South Yorkshire
# 16  E23000010                West Yorkshire
# 17  E12000004                 East Midlands
# 18  E23000018                    Derbyshire
# 19  E23000021                Leicestershire
# ...

# %%
CrimeStats_df['Drug_norm'] = CrimeStats_df['Drug offences']/CrimeStats_df['Drug offences'].max()

# %%
CrimeStats_df.head()
# Out:
#    Area Code                     Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]\n
# 1  E92000001                      ENGLAND
# 2  E12000001                    North East
# 3  E23000013                     Cleveland
# 4  E23000008                        Durham
#
#    Total recorded crime\n (excluding fraud) [note 2]  \
# 0                                            5572143
# 1                                            5228654
# 2                                             296702
# 3                                              83890
# 4                                              66782
#
#    Violence against the person  Homicide  Violence with injury  \
# 0                      2102843       602                573402
# 1                      1974664       573                540855
# 2                       112488        41                 30936
# 3                        31497        15                  7576
# ...

# %%
CrimeStats_df['Weapon_norm'] = CrimeStats_df['Possession of weapons offences']/CrimeStats_df['Possession of weapons offences'].max()

# %%
CrimeStats_df.tail()
# Out:
#     Area Code                 Area Name  \
# 51  W15000004               Dyfed-Powys
# 52  W15000002                     Gwent
# 53  W15000001               North Wales
# 54  W15000003               South Wales
# 55        NaN  British Transport Police
#
#     Total recorded crime\n (excluding fraud) [note 2]  \
# 51                                              44031
# 52                                              60226
# 53                                              61203
# 54                                             109376
# 55                                              68653
#
#     Violence against the person  Homicide  Violence with injury  \
# 51                        21501         5                  3901
# 52                        24824         8                  6344
# 53                        28844         5                  6696
# 54                        41034         9                 12346
# 55                        11976         2                  3260
#
# ...

# %%
CrimeStats_df.hist()
# Out:
# array([[<Axes: title={'center': 'Total recorded crime\n (excluding fraud) [note 2]'}>,
#         <Axes: title={'center': 'Violence against the person'}>,
#         <Axes: title={'center': 'Homicide'}>,
#         <Axes: title={'center': 'Violence with injury'}>,
#         <Axes: title={'center': 'Violence without injury'}>],
#        [<Axes: title={'center': 'Stalking and harassment'}>,
#         <Axes: title={'center': 'Death or serious injury - unlawful driving'}>,
#         <Axes: title={'center': 'Sexual offences'}>,
#         <Axes: title={'center': 'Robbery'}>,
#         <Axes: title={'center': 'Theft offences'}>],
#        [<Axes: title={'center': 'Burglary'}>,
#         <Axes: title={'center': 'Residential burglary'}>,
#         <Axes: title={'center': 'Non-residential burglary'}>,
#         <Axes: title={'center': 'Vehicle offences'}>,
#         <Axes: title={'center': 'Theft from the person'}>],
#        [<Axes: title={'center': 'Bicycle theft'}>,
# ...
